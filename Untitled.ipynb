# %%
file1 = open('qrels.ohsu.88-91', 'r')
Lines = file1.readlines()
i_found = False
t_found = False
i_val = None
t_val = None
print(len(Lines))
for i, line in enumerate(Lines):
    print(line.split('\t'))
# Out:
# 3205
# ['OHSU1', '91226903', '1\n']
# ['OHSU1', '90320756', '1\n']
# ['OHSU1', '91032288', '1\n']
# ['OHSU1', '91336317', '2\n']
# ['OHSU1', '89365014', '1\n']
# ['OHSU1', '88069042', '1\n']
# ['OHSU1', '89184080', '1\n']
# ['OHSU1', '91185608', '2\n']
# ['OHSU1', '89042494', '1\n']
# ['OHSU1', '89093443', '2\n']
# ['OHSU1', '89264075', '1\n']
# ['OHSU1', '88181296', '1\n']
# ['OHSU1', '89270656', '2\n']
# ['OHSU1', '89244872', '2\n']
# ['OHSU1', '88095668', '2\n']
# ['OHSU1', '91110205', '2\n']
# ['OHSU1', '89182887', '2\n']
# ['OHSU1', '91110206', '1\n']
# ['OHSU1', '91123318', '1\n']
# ['OHSU1', '91310766', '1\n']
# ['OHSU1', '91143735', '1\n']
# ['OHSU1', '88103805', '1\n']
# ['OHSU1', '89015550', '1\n']
# ['OHSU1', '89023354', '1\n']
# ['OHSU1', '90383292', '1\n']
# ['OHSU1', '90295182', '1\n']
# ['OHSU1', '90135739', '2\n']
# ['OHSU1', '91243929', '1\n']
# ['OHSU1', '90191478', '2\n']
# ['OHSU1', '89225293', '2\n']
# ['OHSU1', '88238705', '2\n']
# ['OHSU1', '88238706', '2\n']
# ...

# %%
len(Lines)
# Out:
# 3205

# %%
f = open("fixed_query_rels.txt", "w")
for line in Lines:
    old_str_list = line.split('\t')
    new_str = '' + old_str_list[0] + '\t0\t'+old_str_list[1]+'\t'+old_str_list[2][0]+'\n'
    f.write(new_str)

# %%
file1 = open('fixed_query_rels.txt', 'r')
Lines = file1.readlines()
i_found = False
t_found = False
i_val = None
t_val = None
print(len(Lines))
for i, line in enumerate(Lines):
    print(line)
# Out:
# 3205
# OHSU1	0	91226903	1
#
# OHSU1	0	90320756	1
#
# OHSU1	0	91032288	1
#
# OHSU1	0	91336317	2
#
# OHSU1	0	89365014	1
#
# OHSU1	0	88069042	1
#
# OHSU1	0	89184080	1
#
# OHSU1	0	91185608	2
#
# OHSU1	0	89042494	1
#
# OHSU1	0	89093443	2
#
# OHSU1	0	89264075	1
#
# OHSU1	0	88181296	1
#
# OHSU1	0	89270656	2
#
# OHSU1	0	89244872	2
#
# OHSU1	0	88095668	2
#
# OHSU1	0	91110205	2
#
# OHSU1	0	89182887	2
#
# OHSU1	0	91110206	1
#
# OHSU1	0	91123318	1
#
# OHSU1	0	91310766	1
#
# OHSU1	0	91143735	1
#
# OHSU1	0	88103805	1
#
# OHSU1	0	89015550	1
#
# OHSU1	0	89023354	1
#
# OHSU1	0	90383292	1
#
# OHSU1	0	90295182	1
#
# OHSU1	0	90135739	2
#
# OHSU1	0	91243929	1
#
# OHSU1	0	90191478	2
#
# OHSU1	0	89225293	2
#
# OHSU1	0	88238705	2
#
# OHSU1	0	88238706	2
#
# OHSU1	0	88196514	2
#
# OHSU1	0	89201699	2
#
# OHSU1	0	90278894	2
#
# OHSU1	0	89228983	2
#
# OHSU1	0	89201700	2
#
# OHSU1	0	90270361	1
#
# OHSU1	0	91120636	2
#
# OHSU1	0	91016129	1
#
# OHSU1	0	91120637	2
#
# OHSU1	0	91229114	2
#
# OHSU1	0	90320755	1
#
# ...

# %%
file1 = open('boolean_run.txt', 'r')
Lines = file1.readlines()
i_found = False
t_found = False
i_val = None
t_val = None
print(len(Lines))
for i, line in enumerate(Lines):
    print(line)
# Out:
# 3150
# OHSU1 Q0 90059789 1 7.000000 boolean
#
# OHSU1 Q0 88154043 2 6.000000 boolean
#
# OHSU1 Q0 89303719 3 6.000000 boolean
#
# OHSU1 Q0 89078872 4 6.000000 boolean
#
# OHSU1 Q0 90350732 5 6.000000 boolean
#
# OHSU1 Q0 90377812 6 6.000000 boolean
#
# OHSU1 Q0 90191476 7 6.000000 boolean
#
# OHSU1 Q0 90191478 8 6.000000 boolean
#
# OHSU1 Q0 90379605 9 6.000000 boolean
#
# OHSU1 Q0 91110206 10 6.000000 boolean
#
# OHSU1 Q0 91261347 11 6.000000 boolean
#
# OHSU1 Q0 91310751 12 6.000000 boolean
#
# OHSU1 Q0 88020726 13 5.000000 boolean
#
# OHSU1 Q0 88081996 14 5.000000 boolean
#
# OHSU1 Q0 88110225 15 5.000000 boolean
#
# OHSU1 Q0 88089217 16 5.000000 boolean
#
# OHSU1 Q0 88196515 17 5.000000 boolean
#
# OHSU1 Q0 88225408 18 5.000000 boolean
#
# OHSU1 Q0 88260477 19 5.000000 boolean
#
# OHSU1 Q0 88103249 20 5.000000 boolean
#
# OHSU1 Q0 88103361 21 5.000000 boolean
#
# OHSU1 Q0 88152978 22 5.000000 boolean
#
# OHSU1 Q0 88166423 23 5.000000 boolean
#
# ...

# %%
file1 = open('trec_eval/test/qrels.test', 'r')
Lines = file1.readlines()
i_found = False
t_found = False
i_val = None
t_val = None
print(len(Lines))
for i, line in enumerate(Lines):
    print(line)
# Out:
# 3681
# 301 0 CR93E-10279 0
#
# 301 0 CR93E-10505 0
#
# 301 0 CR93E-1282 1
#
# 301 0 CR93E-1850 0
#
# 301 0 CR93E-1860 0
#
# 301 0 CR93E-1952 0
#
# 301 0 CR93E-2191 0
#
# 301 0 CR93E-2473 0
#
# 301 0 CR93E-3103 1
#
# 301 0 CR93E-3284 0
#
# 301 0 CR93E-38 0
#
# 301 0 CR93E-392 0
#
# 301 0 CR93E-4648 0
#
# 301 0 CR93E-4765 0
#
# 301 0 CR93E-4855 0
#
# 301 0 CR93E-5497 0
#
# 301 0 CR93E-5780 0
#
# 301 0 CR93E-5796 1
#
# 301 0 CR93E-5799 1
#
# 301 0 CR93E-6019 0
#
# 301 0 CR93E-6879 0
#
# 301 0 CR93E-6905 1
#
# 301 0 CR93E-7123 0
#
# 301 0 CR93E-7191 0
#
# 301 0 CR93E-7276 0
#
# 301 0 CR93E-7348 1
#
# 301 0 CR93E-7376 1
#
# 301 0 CR93E-7414 0
#
# 301 0 CR93E-7716 0
#
# 301 0 CR93E-7952 1
#
# 301 0 CR93E-8012 0
#
# 301 0 CR93E-8290 1
#
# 301 0 CR93E-8416 1
#
# 301 0 CR93E-8480 0
#
# 301 0 CR93E-8484 0
#
# 301 0 CR93E-9665 1
#
# 301 0 CR93E-9750 1
#
# 301 0 CR93E-9795 0
#
# 301 0 CR93H-10037 1
#
# 301 0 CR93H-10042 0
#
# 301 0 CR93H-10104 0
#
# 301 0 CR93H-10213 0
#
# 301 0 CR93H-10221 0
#
# ...

# %%
file1 = open('trec_eval/test/results.test', 'r')
Lines = file1.readlines()
i_found = False
t_found = False
i_val = None
t_val = None
print(len(Lines))
for i, line in enumerate(Lines):
    print(line)
# Out:
# 1500
# 301	Q0	FR940202-2-00150	104	  2.129133	STANDARD
#
# 301	Q0	FR940202-2-00151	414	  1.724760	STANDARD
#
# 301	Q0	FR940202-2-00154	124	  2.104024	STANDARD
#
# 301	Q0	FR940203-1-00036	233	  1.912871	STANDARD
#
# 301	Q0	FR940203-1-00038	326	  1.800881	STANDARD
#
# 301	Q0	FR940203-1-00039	273	  1.870957	STANDARD
#
# 301	Q0	FR940216-1-00014	470	  1.677013	STANDARD
#
# 301	Q0	FR940303-1-00006	186	  1.999081	STANDARD
#
# 301	Q0	FR940303-1-00012	295	  1.841413	STANDARD
#
# 301	Q0	FR940303-1-00014	407	  1.732111	STANDARD
#
# 301	Q0	FR940303-1-00019	308	  1.820319	STANDARD
#
# 301	Q0	FR940303-1-00021	497	  1.655963	STANDARD
#
# 301	Q0	FR940303-1-00022	11	  2.918622	STANDARD
#
# 301	Q0	FR940404-0-00087	475	  1.674784	STANDARD
#
# 301	Q0	FR940429-0-00128	282	  1.862317	STANDARD
#
# 301	Q0	FR940429-0-00132	297	  1.839996	STANDARD
#
# 301	Q0	FR940503-2-00146	332	  1.799753	STANDARD
#
# 301	Q0	FR940503-2-00147	260	  1.886508	STANDARD
#
# 301	Q0	FR940620-1-00004	109	  2.125475	STANDARD
#
# ...
